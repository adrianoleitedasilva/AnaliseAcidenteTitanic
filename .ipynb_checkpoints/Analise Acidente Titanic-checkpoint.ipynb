# %% [markdown]
# ## Titanic: Analisando o Acidente.
#
# O desafio do Titanic é uma das competições mais famosas, e é promovida pelo site [kaggle.com](http://kaggle.com).
#
# ### A História do Titanic
#
# A história do naufrágio do Titanic é amplamente conhecida. Mesmo com a tecnologia de ponta disponível na época, o navio não resistiu à colisão com um iceberg em 15 de abril de 1912 e acabou afundando. Infelizmente, esse trágico evento resultou na morte de 1502 das 2224 pessoas a bordo.
#
# ![image](https://user-images.githubusercontent.com/6373438/235564554-ffff76c3-7f42-4ae7-8fa3-358944e23d6a.png)
#
# Após o naufrágio do Titanic, muitas pessoas se perguntaram se alguns grupos de passageiros tiveram mais sorte do que outros. Será que crianças e mulheres tiveram mais chances de sobreviver do que homens adultos? E será que a classe em que se encontravam no navio teve um impacto significativo nas chances de sobrevivência? Por exemplo, será que Jack, que viajava na 3ª Classe, teve menos chances de sobreviver do que Rose? Essas são questões interessantes a serem exploradas.
#
# Com os dados reais disponíveis, é possível realizar uma análise exploratória para testar hipóteses e até mesmo construir um modelo preditivo. Imagine descobrir quais seriam suas chances de sobrevivência na 1ª Classe se você tivesse viajado com sua esposa e filho! Essa é apenas uma das possibilidades que esses dados nos permitem explorar.
#
# ### 1 - Definição do Problema
#
# A construção do Titanic durou cerca de dois anos e custou 7,5 milhões de dólares, valores da época. Com dimensões impressionantes de 269 metros de comprimento, 28 metros de largura e 53 metros de altura, o navio contava com uma tripulação de 892 pessoas e tinha capacidade para transportar até 2435 passageiros, distribuídos em três classes.
#
# O Titanic foi projetado para ser o navio mais luxuoso e seguro da época e foi lançado ao mar em 1911, ganhando a reputação de ser "inafundável".
#
# A descrição completa da competição e o conjunto de dados estão disponíveis na página do Kaggle Titanic: Machine Learning from Disaster.
#
# O naufrágio do Titanic foi causado por uma combinação de fatores naturais, como o clima, e humanos, como negligência e excesso de confiança. Infelizmente, 1502 pessoas morreram dos 2224 passageiros a bordo.
#
# Apesar da sorte ter sido um fator importante para a sobrevivência, existem padrões nos dados que mostram que alguns grupos tiveram mais chances de escapar, como mulheres, crianças e passageiros da 1ª Classe. É possível explorar esses padrões por meio de análises exploratórias e modelos preditivos.
#
# ### 2 - Objetivo
#
# Espera-se que você seja capaz de realizar uma análise dos dados disponíveis para identificar as variáveis que tiveram maior influência na probabilidade de sobrevivência dos passageiros. É importante identificar que tipos de pessoas tiveram mais chances de escapar com vida.
#
# Além disso, espera-se que você possa construir um modelo preditivo que possa fornecer previsões de sobrevivência para qualquer passageiro fornecido como input. Ao analisar os dados e construir o modelo, você poderá fornecer insights valiosos sobre o desastre do Titanic e ajudar a prever a probabilidade de sobrevivência de outros passageiros em situações semelhantes.

# %%
# importar os pacotes necessários
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# permitir visualizar todas as colunas
pd.options.display.max_columns = None

#Limpando avisos(warnings) desnecessários
import warnings
warnings.filterwarnings("ignore")

# renderizar os gráficos diretamento no notebook
# %matplotlib inline

# %%
# Lendo os dados de treino e teste
train = pd.read_csv('titanic_train.csv')
test = pd.read_csv('titanic_test.csv')

# %% [markdown]
# **Quantas variáveis (colunas) e quantas entradas (linhas) possui o arquivo?**

# %%
# verificando as dimensões do DataFrame
print("Variáveis:\t{}\nEntradas:\t{}".format(train.shape[1], train.shape[0]))
# Out:
# Variáveis:	12
# Entradas:	891

# %% [markdown]
# ### 3 - Exploração dos Dados
#
# Em uma primeira análise, serão estudadas todas as variáveis relevantes, incluindo nome, tipo, porcentagem de valores faltantes, presença de outliers e tipo de distribuição.
#
# É importante destacar que, como se trata de um aprendizado supervisionado (supervised learning), a variável "Survived" é definida como nossa variável alvo (target). Dessa forma, todas as outras variáveis serão analisadas em relação à sua influência na probabilidade de sobrevivência dos passageiros. Essa análise cuidadosa das variáveis nos permitirá construir um modelo preciso e eficaz que possa prever com precisão a sobrevivência dos passageiros com base em diferentes fatores.
#
# #### Dicionário de Dados
#
# - **PassengerId**: Número de identificação do passageiro
# - **Survived**: Informa se o passageiro sobreviveu ao desastre
#     - **0** - Não
#     - **1** - Sim
# - **Pclass**: Classe do bilhete
#     - **1** - 1ª Classe
#     - **2** - 2ª Classe
#     - **3** - 3ª Classe
# - **Name**: Nome do passageiro
# - **Sex**: Sexo do passageiro
# - **Age**: Idade do passageiro
# - **SibSp**: Quantidade de cônjuges e irmãos a bordo
# - **Parch**: Quantidade de pais e filhos a bordo
# - **Ticket**: Número da passagem
# - **Fare**: Preço da Passagem
# - **Cabin**: Número da cabine do passageiro
# - **Embarked**: Porto no qual o passageiro embarcou
#     - **C** - Cherbourg
#     - **Q** - Queenstown
#     - **S** - Southampton
#
# **Visualizando os tipos de dados de cada variável!**

# %%
display(train.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# Outra forma de visualizar seria com o:

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Utilizando o info() mostramos uma resumo de todo o dataset, sendo a quantidade de informações, colunas, as variáveis e seus tipos e dados faltantes. Isso mesmo, dados que faltam para cada variável(coluna).

# %% [markdown]
# **Visualizando os dados do nosso dataset!**

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **Verificando a quantidade de dados faltantes!**

# %%
# ver a porcentagem valores faltantes
(
    train.isnull().sum() / train.shape[0]
).sort_values(ascending=False)
# Out:
# Cabin          0.771044
# Age            0.198653
# Embarked       0.002245
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# dtype: float64

# %% [markdown]
# **IMPORTANTE** - Abaixo podemos utilizar um HeatMap para visualizar as informações faltantes.
#
# O que for **roxo são informações preenchidas** e **em amarelo, dados faltantes**.

# %%
sns.heatmap(
    train.isnull(), 
    yticklabels=False, 
    cbar=False, 
    cmap='viridis'
)
# Out:
# <Axes: >

# %% [markdown]
# A informação sobre a **Cabin** é a que possui o maior número de informações faltantes, com **mais de 77%**. Após, a coluna **Age** não possui valor em **quase 20%** dos passageiros. Por fim, a coluna informando o **Porto de embarque (Embarked)** possui apenas **2%** de informações faltantes.

# %%
# ver histograma das variáveis numéricas
train.hist(figsize=(10,8))

# %% [markdown]
# **Quais os grupos de pessoas que tinham mais chances de sobrevivência?**

# %%
# Analisar a probabilidade de sobrevivência pelo Sexo
train[['Sex', 'Survived']].groupby(['Sex']).mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
# Plotar os gráficos para Survived vs. Sex, Pclass e Embarked
fig, (axis1, axis2, axis3) = plt.subplots(1,3, figsize=(12,4))

sns.barplot(x='Sex', y='Survived', data=train, ax=axis1)
sns.barplot(x='Pclass', y='Survived', data=train, ax=axis2)
sns.barplot(x='Embarked', y='Survived', data=train, ax=axis3)

# %%
# ver influência da idade na probabilidade de sobrevivência
age_survived = sns.FacetGrid(train, col='Survived')
age_survived.map(sns.distplot, 'Age')

# %%
# plotar uma scatter matrix
columns=['Parch', 'SibSp', 'Age', 'Pclass']
pd.plotting.scatter_matrix(train[columns], figsize=(15, 10))

plt.show()

# %%
# plotar o heatmap para as variáveis numéricas
sns.heatmap(
    train.corr(), 
    cmap='coolwarm', 
    fmt='.2f', 
    linewidths=0.1,
    vmax=1.0, 
    square=True, 
    linecolor='white', 
    annot=True
)

plt.show()

# %% [markdown]
# Pouca gente sabe que o método ```df.describe()``` pode ser usado também para ver algo sobre a estatística descritiva em colunas que não são números. Para isso, é só passar o argumento ```include=['O']```.

# %%
train.describe(include=['O'])
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %% [markdown]
# Olhando esses dados a gente observa que:
#
# - Os valores para ```Name``` são únicos, um para cada pessoa;
# - Não há missing values para ```Name``` e ```Sex```;
# - Existem apenas os sexos ```Masculino``` e ```Feminino```, sendo que o com maior frequência é o Masculino (577/891 = 65%);
# -  O Porto no qual embarcaram mais passageiros é o de S = Southampton.
#
# #### Preparando os dados
#
# Até o momento, o que foi feito foi a importação dos dados para estruturas de DataFrame, a formulação de hipóteses e o início de uma análise exploratória dos dados, além da visualização de gráficos e correlações entre as variáveis relevantes.
#
# No entanto, um projeto de ciência de dados não é uma tarefa linear e restrita a um único caminho. É um processo iterativo que permite voltar atrás e seguir em frente quantas vezes forem necessárias.
#
# Ao examinar um notebook de alguém, pode parecer que tudo está organizado e direcionado ao objetivo final. No entanto, antes de chegar a uma versão final agradável, o processo de ir e voltar ao início é inúmeras vezes.
#
# É importante lembrar que uma versão final é o resultado de várias reescritas. Volte ao início sempre que necessário para adicionar novas informações que façam sentido ao projeto.
#
# **Unindo os datasets**
#
# Uma das melhores práticas ao preparar os dados para um modelo de Machine Learning é combinar os conjuntos de dados de treinamento e teste em um único DataFrame, para depois separá-los novamente.
#
# Ao realizar o feature engineering, como a criação de variáveis dummy ou a codificação de variáveis, o modelo será treinado com base nessa estrutura e os dados de teste devem seguir a mesma arquitetura. Por isso, é mais eficiente realizar todas as etapas em um único DataFrame e dividi-lo novamente em conjuntos de treinamento e teste no final. Dessa forma, você evita erros e reduz a possibilidade de vazamento de dados entre os conjuntos de treinamento e teste, garantindo resultados mais precisos e confiáveis.

# %%
# salvar os índices dos datasets para recuperação posterior
train_idx = train.shape[0]
test_idx = test.shape[0]

# salvar PassengerId para submissao ao Kaggle
passengerId = test['PassengerId']

# extrair coluna 'Survived' e excluir ela do dataset treino
target = train.Survived.copy()
train.drop(['Survived'], axis=1, inplace=True)

# concatenar treino e teste em um único DataFrame
df_merged = pd.concat(objs=[train, test], axis=0).reset_index(drop=True)

print("df_merged.shape: ({} x {})".format(df_merged.shape[0], df_merged.shape[1]))
# Out:
# df_merged.shape: (1309 x 11)

# %% [markdown]
# **Selecionar as features**
#
# Como qualquer conjunto de dados do mundo real, você vai se deparar sempre com dados que não servem para nada e outros que não tem peso ou significância nenhuma no seu modelo.
#
# Muitas vezes nosso julgamento pode ser equivocado, mas infelizmente é papel seu, como cientista de dados, escolher quais features serão usadas para o modelo de Machine Learning.
#
# No nosso caso, vamos desconsiderar as variáveis ```['PassengerId', 'Name', 'Ticket', 'Cabin']```, pois **aparentemente não parecem relevantes**.

# %%
df_merged.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %% [markdown]
# Assim, ficamos com as seguintes variáveis a serem tratadas e preparadas: ```['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']```.
#
# **Valores faltantes**
#
# Vamos dar uma olhada nos valores que faltam em cada columna e tratar esses campos vazios.
#
# Normalmente, há duas abordagens mais utilizadas quando a gente encontra missing values:
#
# - Preencher esses valores arbitrariamente (média, mediana, valor mais frequente);
# - Excluir a linha inteira.
#
# Cada caso é um caso e novamente você, cientista de dados, é quem vai tomar a decisão sobre qual passo seguir.
#
# Na maioria das vezes não é desejável jogar informação de uma linha inteira só por causa de um campo faltando. Sempre que possível é melhor você preencher o campo, e é isso que vamos fazer.

# %%
# completar ou apagar valores faltantes nos datasets de treino e teste
df_merged.isnull().sum()
# Out:
# Pclass        0
# Sex           0
# Age         263
# SibSp         0
# Parch         0
# Fare          1
# Embarked      2
# dtype: int64

# %% [markdown]
# Para as variáveis idade e tarifa, vou colocar o valor da mediana, e para a variável do porto de embarque, vou colocar o valor com maior frequência.

# %%
# age
age_median = df_merged['Age'].median()
df_merged['Age'].fillna(age_median, inplace=True)

# fare
fare_median = df_merged['Fare'].median()
df_merged['Fare'].fillna(fare_median, inplace=True)

# embarked
embarked_top = df_merged['Embarked'].value_counts()[0]
df_merged['Embarked'].fillna(embarked_top, inplace=True)

# %% [markdown]
# #### Verificando as correções feitas

# %%
# completar ou apagar valores faltantes nos datasets de treino e teste
df_merged.isnull().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
sns.heatmap(
    train.isnull(), 
    yticklabels=False, 
    cbar=False, 
    cmap='viridis'
)
# Out:
# <Axes: >

# %% [markdown]
# ### Preparar as variáveis pro modelo
#
# O modelo matemático exige que trabalhemos com variáveis numéricas, ou seja, temos transformar os dados de entrada que estão em formato categoria para números.
#
# Como você vê abaixo, eu convertir os valores possíveis de ```Sex``` para ```{'male': 0, 'female': 1}```. Já em relação à variável ```Embarked```, apliquei o conceito de variáveis dummies.
#
# As variáveis dummies (dummy variables) assumem aqui apenas valores 0 e 1, criando uma nova coluna para cada valor possível da variável categórica. Para ficar mais fácil entender, veja como fica o DataFrame após todos esses tratamentos:

# %%
# converter 'Sex' em 0 e 1
df_merged['Sex'] = df_merged['Sex'].map({'male': 0, 'female': 1})

# dummie variables para 'Embaked'
embarked_dummies = pd.get_dummies(df_merged['Embarked'], prefix='Embarked')
df_merged = pd.concat([df_merged, embarked_dummies], axis=1)
df_merged.drop('Embarked', axis=1, inplace=True)

df_merged.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_914  Embarked_C  \
# 0       3    0  22.0      1      0   7.2500             0           0
# 1       1    1  38.0      1      0  71.2833             0           1
# 2       3    1  26.0      0      0   7.9250             0           0
# 3       1    1  35.0      1      0  53.1000             0           0
# 4       3    0  35.0      0      0   8.0500             0           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %% [markdown]
# **Recuperando os datasets de treino e teste**
#
# Aqui a gente acabou de preparar o dataset para o modelo e vou dividir ```df_merged``` em ```train``` e ```test```, exatamente como era no começo.
#
# Agora você consegue entender a razão da concatenação lá em cima. Teríamos trabalho dobrado e ainda teria o risco de errarmos em alguma etapa.

# %%
# recuperar datasets de treino e teste
train = df_merged.iloc[:train_idx]
test = df_merged.iloc[train_idx:]

# %% [markdown]
# ## Construindo o Modelo
#
# Todo cuidado que tivemos serviu para entender o problema, testar hipóteses e descartar dados desnecessários/redundantes.
#
# Com poucas linhas de código a gente consegue criar e otimizar modelos de Machine Learning básicos. Aqui, vamos construir dois:
#
# - Modelo de Regressão Logística
# - Modelo de Árvore de Decisão

# %%
# importar bibliotecas do modelo de Machine Learning
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
# criar um modelo de Regressão Logística
lr_model = LogisticRegression(solver='liblinear')
lr_model.fit(train, target)

# verificar a acurácia do modelo
acc_logReg = round(lr_model.score(train, target) * 100, 2)
print("Acurácia do modelo de Regressão Logística: {}".format(acc_logReg))
# Out:
# Acurácia do modelo de Regressão Logística: 80.13

# %%
# criar um modelo de árvore de decisão
tree_model = DecisionTreeClassifier(max_depth=3)
tree_model.fit(train, target)

# verificar a acurácia do modelo
acc_tree = round(tree_model.score(train, target) * 100, 2)
print("Acurácia do modelo de Árvore de Decisão: {}".format(acc_tree))
# Out:
# Acurácia do modelo de Árvore de Decisão: 82.72

# %% [markdown]
# # Eu sobreviveria ao Titanic?

# %%
# declarar os valores das variáveis para mim e minha esposa
adriano = np.array([2, 0, 34, 0, 0, 32.2, 0, 0, 0, 1]).reshape((1, -1))

# verificar se nós teríamos sobrevivido
print("Adriano:\t{}".format(tree_model.predict(adriano)[0]))
# Out:
# Adriano:	0

# %% [markdown]
# Claramente, eu morreria no acidente. :/
